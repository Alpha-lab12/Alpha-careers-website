# %% [markdown]
# <a href="https://colab.research.google.com/github/Alpha-lab12/Alpha-careers-website/blob/main/Mazoezi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("helow, Emmanuel")
# Out:
# helow, Emmanuel

# %%
x = 2
y = "Emmanuel"
z = 2.5
print(type(x))
# Out:
# <class 'int'>

# %%
name = "Emmanuel"
print("Hello: Emmanuel")

# %%
#isinstance() checks if a variable belongs to a specific datatype:

a = 100
print(isinstance(a, int))   # True
print(isinstance(a, float)) # False
